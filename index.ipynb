# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab
#
# ## Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.
#
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes
#
# ## Let's get started!

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Rename all the columns to lower case

# %%
new_cols = [col.lower() for col in df.columns]
#set equal to df.columns if you want the change to take place
new_cols
# Out:
# ['c/a',
#  'unit',
#  'scp',
#  'station',
#  'linename',
#  'division',
#  'date',
#  'time',
#  'desc',
#  'entries',
#  'exits                                                               ']

# %% [markdown]
# ## Change the Index to be the Line Names

# %%
df = df.set_index('LINENAME')
df.head()
# Out:
#            C/A  UNIT       SCP STATION DIVISION        DATE      TIME  \
# LINENAME
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#              DESC  ENTRIES  \
# LINENAME
# NQR456W   REGULAR  6736067
# NQR456W   REGULAR  6736087
# NQR456W   REGULAR  6736105
# NQR456W   REGULAR  6736180
# NQR456W   REGULAR  6736349
#
#           EXITS
# LINENAME
# NQR456W                                             2283184
# NQR456W                                             2283188
# NQR456W                                             2283229
# NQR456W                                             2283314
# NQR456W                                             2283384

# %% [markdown]
# ## Change the index back

# %%
df = df.reset_index() 
df.head()
# Out:
#   LINENAME   C/A  UNIT       SCP STATION DIVISION        DATE      TIME  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order
# *Hint: According to the [data dictionary](http://web.mta.info/developers/resources/nyct/turnstile/ts_Field_Description.txt), LINENAME represents all train lines that can be boarded at a given station. Normally lines are represented by one character. For example, LINENAME 456NQR represents trains 4, 5, 6, N, Q, and R.*

# %%
#create column Num_Lines
#seperate LineNames by letter, so we have to seperate them ito a list
#This is the data in the column
#the letters in the string have to be in order of least to greatest
               
df['Num_Lines'] = df.LINENAME.map(lambda x: len(x))

df.head()
#df['Num_Lines'] is the new column
#df.LINENAME.map is defining the information in the column
#lambda x means this is the range od all the info
#and len(x) means we are counting the x values
# Out:
#   LINENAME   C/A  UNIT       SCP STATION DIVISION        DATE      TIME  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
#    Num_Lines
# 0          7
# 1          7
# 2          7
# ...

# %% [markdown]
# ## Write a function to clean a column name

# %%
def clean(name_col):
    cleaned = name_col.title()
    return cleaned
#df.head()
#We can also check an individual column type rather then all 
#df['UNIT'] = df.UNIT.astype(float) #Changing the column to float
#df.head() #Checking our changes
df.columns = [clean(i) for i in df.columns]
df
# Out:
#        Linename    C/A  Unit       Scp        Station Division        Date  \
# 0       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/25/2018
# 1       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/25/2018
# 2       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/25/2018
# 3       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/25/2018
# 4       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/25/2018
# 5       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/25/2018
# 6       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/26/2018
# 7       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/26/2018
# 8       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/26/2018
# 9       NQR456W   A002  R051  02-00-00          59 ST      BMT  08/26/2018
# 10      NQR456W   A002  R051  02-00-00          59 ST      BMT  08/26/2018
# ...

# %%
# This is a list comprehension. It applies your clean function to every item in the list.
# We then reassign that to df.columns
# You shouldn't have to change anything here.
# Your function above should work appropriately here.
#df.columns = [clean('EXITS') for col in df.columns]

# %%
# Checking the output, we can see the results.
df.columns

# %% [markdown]
# ## Group the Data by Day of Week and Plot the Sum of The Numeric Columns

# %%
df.head()
# Out:
#   Linename   C/A  Unit       Scp Station Division        Date      Time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#       Desc  Entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    Exits                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
#    Num_Lines
# 0          7
# 1          7
# 2          7
# ...

# %%
df.Date = pd.to_datetime(df.Date)
df['Dayofweek'] = df.Date.dt.dayofweek
grouped = df.groupby('Dayofweek').sum()
grouped.plot(kind='barh')

# %%
df.head()
# Out:
#   Linename   C/A  Unit       Scp Station Division       Date      Time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT 2018-08-25  16:00:00
#
#       Desc  Entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    Exits                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
#    Num_Lines  Dayofweek
# 0          7          5
# ...

# %%
df.Dayofweek
# Out:
# 0         5
# 1         5
# 2         5
# 3         5
# 4         5
# 5         5
# 6         6
# 7         6
# 8         6
# 9         6
# 10        6
# 11        6
# 12        0
# 13        0
# 14        0
# 15        0
# 16        0
# 17        0
# 18        1
# 19        1
# 20        1
# 21        1
# 22        1
# 23        1
# 24        2
# 25        2
# 26        2
# 27        2
# 28        2
# 29        2
#          ..
# 197595    0
# 197596    0
# 197597    0
# 197598    0
# 197599    0
# 197600    0
# 197601    1
# 197602    1
# 197603    1
# 197604    1
# 197605    1
# 197606    1
# 197607    2
# 197608    2
# 197609    2
# 197610    2
# 197611    2
# 197612    2
# 197613    3
# 197614    3
# 197615    3
# 197616    3
# 197617    3
# 197618    3
# 197619    4
# 197620    4
# 197621    4
# 197622    4
# 197623    4
# 197624    4
# Name: Dayofweek, Length: 197625, dtype: int64

# %% [markdown]
# ## Group the Data by Weekend/Weekday and Plot the Sum of the Numeric Columns

# %%
wkend.columns
# Out:
# Index(['Entries',
#        'Exits                                                               ',
#        'Num_Lines', 'Dayofweek'],
#       dtype='object')

# %%
df['Isweekend'] = df.Dayofweek.map({0:False,1:False,2:False,3:False,4:False,5:True,6:True})
wkend = df.groupby('Isweekend').sum()
wkend[['Entries','Exits                                                               ']].plot(kind='barh')

# %% [markdown]
# ## Analysis Question:
#
# What is misleading about the day of week and weekend/weekday charts you just plotted?

# %%
# Your answer here

# %% [markdown]
# ## Drop a couple of columns

# %%
# Your code here
df = df.drop(['UNIT', 'STATION'], axis=1)
df.head()
# Out:
#   LINENAME   C/A       SCP DIVISION       DATE      TIME     DESC  \
# 0  NQR456W  A002  02-00-00      BMT 2018-08-25  00:00:00  REGULAR
# 1  NQR456W  A002  02-00-00      BMT 2018-08-25  04:00:00  REGULAR
# 2  NQR456W  A002  02-00-00      BMT 2018-08-25  08:00:00  REGULAR
# 3  NQR456W  A002  02-00-00      BMT 2018-08-25  12:00:00  REGULAR
# 4  NQR456W  A002  02-00-00      BMT 2018-08-25  16:00:00  REGULAR
#
#    EXITS                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
#    Num_Lines  Dayofweek
# 0          7          5
# 1          7          5
# 2          7          5
# 3          7          5
# 4          7          5

# %% [markdown]
# ## Summary
#
# Great! You practiced your data cleanup-skills using Pandas.
